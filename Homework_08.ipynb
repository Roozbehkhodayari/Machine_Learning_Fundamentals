# %% [markdown]
# ## Homework 08: Classification
#
# ### Due: July 5th @ 11:59pm (with usual 2 hour + 1 minute grace period)
#
#
# In this final homework before starting our course project, we will introduce the essential machine learning paradigm of **classification**. We will work with the **UCI Adult** dataset. This is a binary classification task.
#
# As we’ve discussed in this week’s lessons, the classification workflow is similar to what we’ve done for regression, with a few key differences:
# - We use `StratifiedKFold` instead of plain `KFold` so that every fold keeps the original class proportions.
# - We use classification metrics (e.g., accuracy, precision, recall, F1-score for binary classification) instead of regression metrics.
# - We could explore misclassified instances through a confusion matrix (though we will not do that in this homework).
#
# For this assignment, you’ll build a gradient boosting classification using `HistGradientBoostingClassifier` (HGBC) and explore ways of tuning the hyperparameters, including using the technique of early stopping, which basically avoiding have to tune the number of estimators (called `max_iter` in HGBC).
#
# HGBC has many advantages, which we explain below.
#
#
# ### Grading
#
# There are 11 graded problems, each worth 5 points.

# %%
# General utilities
import os
import io
import time
import zipfile
import requests
from collections import Counter

# Data handling and visualization
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
from IPython.display import display
 
# Data source
from sklearn.datasets import fetch_openml

 
# scikit-learn core tools 
from sklearn.model_selection import (
    train_test_split,
    cross_val_score,
    StratifiedKFold,
    RandomizedSearchCV
)

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OrdinalEncoder

 
# Import model 
from sklearn.ensemble import HistGradientBoostingClassifier
 
# Metrics
from sklearn.metrics import balanced_accuracy_score, classification_report, precision_score, recall_score, f1_score
 
# Distributions for random search
from scipy.stats import loguniform, randint, uniform

# pandas dtypes helpers
from pandas.api.types import is_numeric_dtype, is_categorical_dtype
from pandas import CategoricalDtype

# Optuna Hyperparameter Search tool    (may need to be installed)
import optuna


# Misc

random_seed = 42

def format_hms(seconds):
    return time.strftime("%H:%M:%S", time.gmtime(seconds))

# %% [markdown]
# ### Prelude 0: Installing Optuna (if needed)
#
# Optuna is not included in every Python installation. If the statement
#
# ```python
# import optuna
# ```
#
# produces
#
# ```
# ModuleNotFoundError: No module named 'optuna'
# ```
#
# then install it using one of the following methods.
#
# **If you are using Anaconda (recommended):**
#
# ```bash
# conda install -c conda-forge optuna
# ```
#
# **Or using pip:**
#
# ```bash
# pip install optuna
# ```
#
# If you are working in a Jupyter notebook, you can also install it directly from a code cell:
#
# ```python
# %pip install optuna
# ```
#
# or
#
# ```python
# !pip install optuna
# ```
#
# After the installation finishes, **restart the Jupyter kernel** and rerun the notebook from the beginning.

# %% [markdown]
# ### Prelude 1: Load and Preprocess the UCI Adult Income Dataset
#
# - Load the dataset from sklearn
# - Preliminary EDA
# - Feature Engineering

# %%
# Load and clean
df = fetch_openml(name='adult', version=2, as_frame=True).frame

df.replace("?", np.nan, inplace=True)            # Some datasets use ? instead of Nan for missing data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48842 non-null  int64
#  1   workclass       46043 non-null  category
#  2   fnlwgt          48842 non-null  int64
#  3   education       48842 non-null  category
#  4   education-num   48842 non-null  int64
#  5   marital-status  48842 non-null  category
#  6   occupation      46033 non-null  category
#  7   relationship    48842 non-null  category
#  8   race            48842 non-null  category
#  9   sex             48842 non-null  category
#  10  capital-gain    48842 non-null  int64
#  11  capital-loss    48842 non-null  int64
#  12  hours-per-week  48842 non-null  int64
#  13  native-country  47985 non-null  category
#  14  class           48842 non-null  category
# dtypes: category(9), int64(6)
# memory usage: 2.7 MB

# %% [markdown]
# #### Check: Is the dataset imbalanced?

# %%
print(df['class'].value_counts(normalize=True))
# Out:
# class
# <=50K    0.760718
# >50K     0.239282
# Name: proportion, dtype: float64

# %% [markdown]
# **YES:** It looks like this dataset is somewhat imbalanced. Therefore, we will
# 1. Tell the model to compensate during training by setting `class_weight='balanced'` when defining the model;
# 2. Evaluate it `balanced_accuracy` instead of `accuracy` and with class-aware metrics (precision, recall, F1); and
# 3. [Optional] Adjust the probability threshold instead of relying on raw accuracy alone after examining the precision-recall trade-off you observe at 0.5.

# %% [markdown]
# ### Feature Engineering
#
# Based on the considerations in **Appendix One**, we'll make the following changes to the dataset to facilitate training:
#
#
# 1. Drop `fnlwgt` and `education`.
# 3. Replace `capital-gain` and `capital-loss` by their difference `capital_net` and add a log-scaled version `capital_net_log`.

# %%
# Drop the survey-weight column
df_eng = df.drop(columns=["fnlwgt"])

# Keep only the ordinal education feature
df_eng = df_eng.drop(columns=["education"])      # retain 'education-num'

# Combine capital gains and losses, add a log-scaled variant
df_eng["capital_net"]     = df_eng["capital-gain"] - df_eng["capital-loss"]
df_eng["capital_net_log"] = np.log1p(df_eng["capital_net"].clip(lower=0))
df_eng = df_eng.drop(columns=["capital-gain", "capital-loss"])

# check
df_eng.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        46043 non-null  category
#  2   education-num    48842 non-null  int64
#  3   marital-status   48842 non-null  category
#  4   occupation       46033 non-null  category
#  5   relationship     48842 non-null  category
#  6   race             48842 non-null  category
#  7   sex              48842 non-null  category
#  8   hours-per-week   48842 non-null  int64
#  9   native-country   47985 non-null  category
#  10  class            48842 non-null  category
#  11  capital_net      48842 non-null  int64
#  12  capital_net_log  48842 non-null  float64
# dtypes: category(8), float64(1), int64(4)
# memory usage: 2.2 MB

# %% [markdown]
# #### Separate target and split
#
# Create the feature set `X` and the target set `y` (using `class` as the target) and split the dataset into 80% training and 20% testing sets, making sure to stratify.

# %%
X = df_eng.drop(columns=["class"])
y = (df_eng["class"] == ">50K").astype(int)

# Split (with stratification)
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    random_state=random_seed,
    stratify=y                           # So same proportion of classes in train and test sets
)

print("Train:", X_train.shape, y_train.shape)
print("Test :", X_test.shape,  y_test.shape)
# Out:
# Train: (39073, 12) (39073,)
# Test : (9769, 12) (9769,)

# %% [markdown]
# ### Prelude 2: Create a data pipeline and the `HistGradientBoostingClassifier` model
#
# Histogram-based gradient boosting improves on the standard version by:
#
# * **Histogram splits:** bins each feature into ≤ `max_bins` quantiles (i.e., each bin is approximately the same size) and tests splits only between bins, slashing compute time and scaling to large data sets. Default for `max_bins` = 255.
# * **Native NaN handling:** treats missing values as their own bin—no imputation needed.
# * **Native Categorical Support**: accepts integer-encoded categories directly and tests “category c vs. all others” splits, eliminating one-hot blow-ups and fake orderings.
# * **Built-in early stopping:** stops training after no improvement in validation loss after `n_iter_no_change` rounds. `tol` defines "improvement" (default is 1e-7).
# * **Leaf shrinkage:** adds `l2_regularization`, which ridge-shrinks each leaf value (without changing tree shape) so tiny, noisy leaves have less effect.
#
# >**Summary:**  Histogram-based GB trades a tiny approximation error (binning) for a **huge speed-up** and adds extra conveniences, making it the preferred choice for large tabular data sets. Tuning workflow relies on **Early stopping** to stop training before overfitting occurs.

# %%
# Define a baseline model 

HGBC_model = HistGradientBoostingClassifier(
    # tree structure and learning rate
    learning_rate=0.1,            # These 5 parameters are at defaults for our baseline training in Problem 1             
    max_leaf_nodes=31,            # but will be tuned by randomized search in Problem 2 and Optuna in Problem 3               
    max_depth=None,               
    min_samples_leaf=20,          
    l2_regularization=0.0,        

    # bins and iteration
    max_bins=255,                 # default
    max_iter=500,                 # high enough for early stopping
    early_stopping=True,
    n_iter_no_change=20,
    validation_fraction=0.2,      # 20% monitored for early stopping
    tol=1e-7,                     # default tolerance for validation improvement

    # class imbalance
    class_weight="balanced",

    random_state=random_seed,
    verbose=0
)

# %% [markdown]
# ### Create a pipeline appropriate for HGBC
#
# **Why use a `Pipeline` instead of encoding in the dataset first?**
#
# * **Avoid data leakage.** In each CV fold, the `OrdinalEncoder` is refit only on that fold’s training data, so the validation split never influences the encoder.
# * **Single, reusable object.** The pipeline bundles preprocessing + model, letting you call `fit`/`predict` on raw data anywhere (CV, Optuna, production) with identical behavior.
# * **Compatible with search tools.** `cross_validate`, `GridSearchCV`, and Optuna expect an estimator that can be cloned and refit; a pipeline meets that requirement automatically.
#
# Put simply, the pipeline gives you leak-free evaluation and portable, hassle-free tuning without extra code.

# %%
enc = OrdinalEncoder(
    handle_unknown="use_encoded_value",   # Allow unseen categories during transform
    unknown_value=-1,                     # Code for unseen categories
    encoded_missing_value=-2,             # Code for missing values (NaN)
    dtype=np.int64                        # Needed for HistGradientBoostingClassifier
)

# Categorical features
cat_cols = X.select_dtypes(exclude=["number"]).columns.tolist()

# Numeric features (everything that isn’t object / category)
num_cols = X.select_dtypes(include=["number"]).columns.tolist()

preprocess = ColumnTransformer(
    [("cat", enc, cat_cols),
     ("num", "passthrough", num_cols)]
)

pipelined_model = Pipeline([
    ("prep", preprocess),
    ("gb",   HGBC_model)
])

# %% [markdown]
# ## Problem 1: Baseline Cross-Validation with F1
#
# In this problem, you will run a baseline cross-validation evaluation of your `HistGradientBoostingClassifier` pipeline, using `HGBC_model` defined above.
#
# **Background:**
#
# * Since the Adult dataset is imbalanced (about 24% positives, 76% negatives), accuracy alone is not reliable.
# * We will use the **F1 score** as the evaluation metric, since it balances precision (avoiding false positives) and recall (avoiding false negatives) in a single measure. This is a fairer metric for imbalanced classification, where both types of error matter.
# * We will apply **5-fold stratified cross-validation** to make sure each fold has the same proportion of the classes as the original dataset.
# * Repeated cross-validation is optional and not required here, because the Adult dataset is large and `HistGradientBoostingClassifier` is robust to small sampling differences.
#
# **Instructions:**
#
# 1. Set up a `StratifiedKFold` cross-validation object with 5 splits, shuffling enabled, and `random_state=random_seed`.
# 2. Use `cross_val_score` to estimate the mean F1 score and its standard deviation across the folds.
# 3. Print out the mean and standard deviation of the F1 score, rounded to 4 decimal places.
# 4. Answer the graded question.

# %%
# Your code here
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=random_seed)
baseline_f1_scores  = cross_val_score(pipelined_model, X_train, y_train, cv=cv, scoring="f1", n_jobs=-1)
baseline_mean_f1  = np.mean(baseline_f1_scores)
std_f1 = np.std(baseline_f1_scores)

print(f" F1 Scores: {baseline_f1_scores}")
print(f"Mean F1 Score: {baseline_mean_f1:.4f}")
print(f"Std F1 Score: {std_f1:.4f}")
# Out:
#  F1 Scores: [0.71761542 0.71247818 0.71314031 0.7119448  0.7065073 ]
# Mean F1 Score: 0.7123
# Std F1 Score: 0.0035

# %% [markdown]
# ### Problem 1 Graded Answer
#
# Set `a1` to the mean F1 score of the baseline model.

# %%
 # Your answer here

a1 = baseline_mean_f1                     # replace 0 with an expression

# %%
# DO NOT change this cell in any way

print(f'a1 = {a1:.4f}')
# Out:
# a1 = 0.7123

# %% [markdown]
# ## Problem 2: Hyperparameter Optimization with Randomized Search for F1
#
# In this problem, you will tune your `pipelined_model` using `RandomizedSearchCV` to identify the best combination of tree structure and learning rate parameters that maximize the **F1 score**.
#
# **Background:**
# The F1 score is our main metric because it balances precision and recall on an imbalanced dataset. Optimizing hyperparameters for F1 ensures we manage both false positives and false negatives in a single measure.
#
# **Instructions:**
#
# 1. Set up a randomized search over the following hyperparameter ranges, using appropriate random-number distributions:
#
#    * `learning_rate` (log-uniform between 1e-3 and 0.3)
#    * `max_leaf_nodes` (integer from 16 to 256)
#    * `max_depth` (integer from 2 to 10)
#    * `min_samples_leaf` (integer from 10 to 200)
#    * `l2_regularization` (uniform between 0.0 and 2.0)
# 2. Use **5-fold stratified cross-validation**, with the same settings as in Problem 1.
# 3. Start `n_iter` at 10 or 20 to prototype, but try for 50 - 100 trials. More trials will generally yield better results, if your time and machine allow.
# 4. After running the search, show a neatly formatted table of the top 5 results, using `display(...)` showing their mean F1 scores, standard deviation, and the chosen hyperparameter values.
# 5. Answer the graded question.

# %%
# Your code here
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=random_seed)
param_distributions = {
    "gb__learning_rate": loguniform(0.001, 0.3),
    "gb__max_leaf_nodes": randint(16, 257),
    "gb__max_depth": randint(2, 11),
    "gb__min_samples_leaf": randint(10, 201),
    "gb__l2_regularization": uniform(0, 2)
}

random_search_f1  = RandomizedSearchCV(
    estimator=pipelined_model,
    param_distributions=param_distributions,
    n_iter=100,                     
    scoring="f1",                  
    cv=cv,
    n_jobs=-1,                     
    random_state=random_seed,
    verbose=1,
    return_train_score=True                    
)

random_search_f1.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#                    estimator=Pipeline(steps=[('prep',
#                                               ColumnTransformer(transformers=[('cat',
#                                                                                OrdinalEncoder(dtype=<class 'numpy.int64'>,
#                                                                                               encoded_missing_value=-2,
#                                                                                               handle_unknown='use_encoded_value',
#                                                                                               unknown_value=-1),
#                                                                                ['workclass',
#                                                                                 'marital-status',
#                                                                                 'occupation',
#                                                                                 'relationship',
#                                                                                 'race',
#                                                                                 'sex',
#                                                                                 'native...
#                                         'gb__max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x00000253975DEC00>,
#                                         'gb__max_leaf_nodes': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x00000253975DCF50>,
#                                         'gb__min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x00000253975DED20>},
#                    random_state=42, return_train_score=True, scoring='f1',
#                    verbose=1)

# %%
results = pd.DataFrame(random_search_f1.cv_results_)

top5_results = (results.sort_values("rank_test_score").
                loc[:, [
                        "rank_test_score",
                        "mean_test_score",
                        "std_test_score",
                        "param_gb__learning_rate",
                        "param_gb__max_leaf_nodes",
                        "param_gb__max_depth",
                        "param_gb__min_samples_leaf",
                        "param_gb__l2_regularization"]].
                        head(5).rename(columns={
                                                "rank_test_score": "rank",
                                                "mean_test_score": "mean_f1",
                                                "std_test_score": "std_f1",
                                                "param_gb__learning_rate": "learning_rate",
                                                "param_gb__max_leaf_nodes": "max_leaf_nodes",
                                                "param_gb__max_depth": "max_depth",
                                                "param_gb__min_samples_leaf": "min_samples_leaf",
                                                "param_gb__l2_regularization": "l2_regularization"}))
display(top5_results)
# Out:
#     rank   mean_f1    std_f1  learning_rate  max_leaf_nodes  max_depth  \
# 19     1  0.712000  0.003063       0.127541              48          3
# 60     2  0.711962  0.004237       0.268164             206          5
# 21     3  0.711405  0.003213       0.157664             242          2
# 59     4  0.711045  0.003477       0.229549              61          2
# 14     5  0.711026  0.002790       0.070991              39          6
#
#     min_samples_leaf  l2_regularization
# 19                57           1.829919
# 60               169           1.144585
# 21               110           1.275115
# 59               190           1.495438
# 14               163           1.689068

# %%
print(f"Best mean F1: {random_search_f1.best_score_:.4f}")
print("Best parameters:")
print(random_search_f1.best_params_)
# Out:
# Best mean F1: 0.7120
# Best parameters:
# {'gb__l2_regularization': np.float64(1.8299193510875615), 'gb__learning_rate': np.float64(0.12754065069696732), 'gb__max_depth': 3, 'gb__max_leaf_nodes': 48, 'gb__min_samples_leaf': 57}

# %% [markdown]
# ### Problem 2 Graded Answer
#
# Set `a2` to the mean F1 score of the best model found.

# %%
 # Your answer here

a2 = random_search_f1.best_score_                     # replace 0 with your answer, may copy from the displayed results

# %%
# DO NOT change this cell in any way

print(f'a2 = {a2:.4f}')
# Out:
# a2 = 0.7120

# %% [markdown]
# ## Problem 3: Hyperparameter Optimization with Optuna for F1
#
# In this problem, you will explore **Optuna**, a powerful hyperparameter optimization framework, to identify the best combination of hyperparameters that maximize the F1 score of your `pipelined_model`.
#
# **Background:**
# Optuna uses a smarter sampling strategy than grid search or randomized search, allowing you to explore the hyperparameter space more efficiently. It also supports *pruning*, which can stop unpromising trials early to save time. This makes it a popular SOTA optimization tool.
#
# **Before you start** browse the [Optuna documentation](https://optuna.org) and view the [tutorial video](https://optuna.readthedocs.io/en/stable/tutorial/index.html).
#
# As before, we focus on the **F1 score** because it balances precision and recall, making it more robust on an imbalanced dataset.
#
# **Instructions:**
#
# 1. Define an Optuna objective function to optimize F1 score, sampling the exact same hyperparameter ranges you did in Problem 2 and using the same CV settings.
# 3. Set up an Optuna study with a reasonable number of trials (e.g., up to 100 depending on runtime resources--on my machine Optuna runs about 10x faster than randomized search for the same number of trials, but YMMV).
# 4. After running the optimization, `display` a clean table with the top 5 trials showing their F1 scores and corresponding hyperparameter settings.
# 5. Answer the graded question.
#
# **Note:**  There are many resources on Optuna you can find on the web, but for this problem, you have my permission to let ChatGPT write the code for you.

# %%
# Your code here
from sklearn.base import clone

cv = StratifiedKFold(n_splits=5,shuffle=True,random_state=random_seed)

def objective(trial):
    params = {
        "gb__learning_rate": trial.suggest_float("gb__learning_rate", 1e-3, 0.3, log=True),
        "gb__max_leaf_nodes": trial.suggest_int("gb__max_leaf_nodes", 16, 256),
        "gb__max_depth": trial.suggest_int("gb__max_depth", 2, 10),
        "gb__min_samples_leaf": trial.suggest_int("gb__min_samples_leaf", 10, 200),
        "gb__l2_regularization": trial.suggest_float("gb__l2_regularization", 0.0, 2.0)}
    
    model = clone(pipelined_model)
    model.set_params(**params)
    
    scores = cross_val_score(model,X_train,y_train,cv=cv,scoring="f1",n_jobs=-1)
    
    return scores.mean()

# %%
study = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler(seed=random_seed))

study.optimize(objective,n_trials=100,show_progress_bar=True)
# Out:
# [I 2026-06-28 23:11:33,202] A new study created in memory with name: no-name-07ebf1c4-f70b-4ff8-9ecc-09deaa65564e
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2026-06-28 23:11:41,987] Trial 0 finished with value: 0.6932940220816347 and parameters: {'gb__learning_rate': 0.008468008575248327, 'gb__max_leaf_nodes': 245, 'gb__max_depth': 8, 'gb__min_samples_leaf': 124, 'gb__l2_regularization': 0.31203728088487304}. Best is trial 0 with value: 0.6932940220816347.
# [I 2026-06-28 23:11:48,536] Trial 1 finished with value: 0.6757628077310386 and parameters: {'gb__learning_rate': 0.0024345423962016913, 'gb__max_leaf_nodes': 29, 'gb__max_depth': 9, 'gb__min_samples_leaf': 124, 'gb__l2_regularization': 1.416145155592091}. Best is trial 0 with value: 0.6932940220816347.
# [I 2026-06-28 23:11:59,049] Trial 2 finished with value: 0.6737028554087643 and parameters: {'gb__learning_rate': 0.001124579825911934, 'gb__max_leaf_nodes': 249, 'gb__max_depth': 9, 'gb__min_samples_leaf': 50, 'gb__l2_regularization': 0.36364993441420124}. Best is trial 0 with value: 0.6932940220816347.
# [I 2026-06-28 23:12:06,004] Trial 3 finished with value: 0.6702328589793822 and parameters: {'gb__learning_rate': 0.002846526357761094, 'gb__max_leaf_nodes': 89, 'gb__max_depth': 6, 'gb__min_samples_leaf': 92, 'gb__l2_regularization': 0.5824582803960838}. Best is trial 0 with value: 0.6932940220816347.
# [I 2026-06-28 23:12:10,635] Trial 4 finished with value: 0.7072303165616105 and parameters: {'gb__learning_rate': 0.032781876533976156, 'gb__max_leaf_nodes': 49, 'gb__max_depth': 4, 'gb__min_samples_leaf': 79, 'gb__l2_regularization': 0.9121399684340719}. Best is trial 4 with value: 0.7072303165616105.
# [I 2026-06-28 23:12:14,609] Trial 5 finished with value: 0.7106934565679892 and parameters: {'gb__learning_rate': 0.08810003129071789, 'gb__max_leaf_nodes': 64, 'gb__max_depth': 6, 'gb__min_samples_leaf': 123, 'gb__l2_regularization': 0.09290082543999545}. Best is trial 5 with value: 0.7106934565679892.
# [I 2026-06-28 23:12:18,291] Trial 6 finished with value: 0.6924582687003562 and parameters: {'gb__learning_rate': 0.03198617182203562, 'gb__max_leaf_nodes': 57, 'gb__max_depth': 2, 'gb__min_samples_leaf': 191, 'gb__l2_regularization': 1.9312640661491187}. Best is trial 5 with value: 0.7106934565679892.
# [I 2026-06-28 23:12:21,831] Trial 7 finished with value: 0.7077598934727538 and parameters: {'gb__learning_rate': 0.10057690178153984, 'gb__max_leaf_nodes': 89, 'gb__max_depth': 2, 'gb__min_samples_leaf': 140, 'gb__l2_regularization': 0.8803049874792026}. Best is trial 5 with value: 0.7106934565679892.
# [I 2026-06-28 23:12:25,684] Trial 8 finished with value: 0.6158150355713565 and parameters: {'gb__learning_rate': 0.002005873336344495, 'gb__max_leaf_nodes': 135, 'gb__max_depth': 2, 'gb__min_samples_leaf': 183, 'gb__l2_regularization': 0.5175599632000338}. Best is trial 5 with value: 0.7106934565679892.
# [I 2026-06-28 23:12:30,981] Trial 9 finished with value: 0.7086410872976341 and parameters: {'gb__learning_rate': 0.043767126303409544, 'gb__max_leaf_nodes': 91, 'gb__max_depth': 6, 'gb__min_samples_leaf': 114, 'gb__l2_regularization': 0.3697089110510541}. Best is trial 5 with value: 0.7106934565679892.
# [I 2026-06-28 23:12:31,935] Trial 10 finished with value: 0.7111000297077477 and parameters: {'gb__learning_rate': 0.2508415478916109, 'gb__max_leaf_nodes': 184, 'gb__max_depth': 6, 'gb__min_samples_leaf': 13, 'gb__l2_regularization': 0.0419665897097137}. Best is trial 10 with value: 0.7111000297077477.
# [I 2026-06-28 23:12:33,076] Trial 11 finished with value: 0.7094211866233585 and parameters: {'gb__learning_rate': 0.20602503693341606, 'gb__max_leaf_nodes': 177, 'gb__max_depth': 6, 'gb__min_samples_leaf': 25, 'gb__l2_regularization': 0.00761232731738435}. Best is trial 10 with value: 0.7111000297077477.
# [I 2026-06-28 23:12:34,004] Trial 12 finished with value: 0.7099534285296717 and parameters: {'gb__learning_rate': 0.29254049614812955, 'gb__max_leaf_nodes': 184, 'gb__max_depth': 7, 'gb__min_samples_leaf': 21, 'gb__l2_regularization': 0.03469393470018437}. Best is trial 10 with value: 0.7111000297077477.
# [I 2026-06-28 23:12:38,157] Trial 13 finished with value: 0.7101490223482164 and parameters: {'gb__learning_rate': 0.0898694335357224, 'gb__max_leaf_nodes': 198, 'gb__max_depth': 4, 'gb__min_samples_leaf': 159, 'gb__l2_regularization': 0.007372551539117554}. Best is trial 10 with value: 0.7111000297077477.
# [I 2026-06-28 23:12:40,695] Trial 14 finished with value: 0.7113216482785385 and parameters: {'gb__learning_rate': 0.12025195377180907, 'gb__max_leaf_nodes': 134, 'gb__max_depth': 4, 'gb__min_samples_leaf': 61, 'gb__l2_regularization': 0.6952668609931651}. Best is trial 14 with value: 0.7113216482785385.
# [I 2026-06-28 23:12:43,182] Trial 15 finished with value: 0.7122148284019028 and parameters: {'gb__learning_rate': 0.15817490209956087, 'gb__max_leaf_nodes': 140, 'gb__max_depth': 4, 'gb__min_samples_leaf': 55, 'gb__l2_regularization': 0.9130867133019255}. Best is trial 15 with value: 0.7122148284019028.
# [I 2026-06-28 23:12:47,758] Trial 16 finished with value: 0.6898178124021304 and parameters: {'gb__learning_rate': 0.012170307466212374, 'gb__max_leaf_nodes': 137, 'gb__max_depth': 4, 'gb__min_samples_leaf': 56, 'gb__l2_regularization': 1.0465208753793416}. Best is trial 15 with value: 0.7122148284019028.
# [I 2026-06-28 23:12:51,452] Trial 17 finished with value: 0.7118782051632441 and parameters: {'gb__learning_rate': 0.1263975521575654, 'gb__max_leaf_nodes': 138, 'gb__max_depth': 3, 'gb__min_samples_leaf': 47, 'gb__l2_regularization': 1.2898506477858533}. Best is trial 15 with value: 0.7122148284019028.
# [I 2026-06-28 23:12:55,203] Trial 18 finished with value: 0.7101832987649734 and parameters: {'gb__learning_rate': 0.0615186043398763, 'gb__max_leaf_nodes': 154, 'gb__max_depth': 3, 'gb__min_samples_leaf': 39, 'gb__l2_regularization': 1.2911188551906405}. Best is trial 15 with value: 0.7122148284019028.
# [I 2026-06-28 23:12:59,190] Trial 19 finished with value: 0.6892710510288488 and parameters: {'gb__learning_rate': 0.017190589694028514, 'gb__max_leaf_nodes': 219, 'gb__max_depth': 3, 'gb__min_samples_leaf': 81, 'gb__l2_regularization': 1.6291802573602858}. Best is trial 15 with value: 0.7122148284019028.
# [I 2026-06-28 23:13:01,196] Trial 20 finished with value: 0.7116831951510181 and parameters: {'gb__learning_rate': 0.16569332066643666, 'gb__max_leaf_nodes': 105, 'gb__max_depth': 5, 'gb__min_samples_leaf': 36, 'gb__l2_regularization': 1.1802486217549215}. Best is trial 15 with value: 0.7122148284019028.
# [I 2026-06-28 23:13:03,090] Trial 21 finished with value: 0.7120579376502891 and parameters: {'gb__learning_rate': 0.17056384555858647, 'gb__max_leaf_nodes': 119, 'gb__max_depth': 5, 'gb__min_samples_leaf': 37, 'gb__l2_regularization': 1.2095167694395839}. Best is trial 15 with value: 0.7122148284019028.
# [I 2026-06-28 23:13:05,601] Trial 22 finished with value: 0.7112195010277225 and parameters: {'gb__learning_rate': 0.1509259926390877, 'gb__max_leaf_nodes': 109, 'gb__max_depth': 5, 'gb__min_samples_leaf': 69, 'gb__l2_regularization': 1.5122300078086828}. Best is trial 15 with value: 0.7122148284019028.
# [I 2026-06-28 23:13:09,385] Trial 23 finished with value: 0.7087809482682409 and parameters: {'gb__learning_rate': 0.054950224276395926, 'gb__max_leaf_nodes': 159, 'gb__max_depth': 3, 'gb__min_samples_leaf': 40, 'gb__l2_regularization': 1.7139492803002523}. Best is trial 15 with value: 0.7122148284019028.
# [I 2026-06-28 23:13:10,633] Trial 24 finished with value: 0.7093664046787734 and parameters: {'gb__learning_rate': 0.29920917552181403, 'gb__max_leaf_nodes': 119, 'gb__max_depth': 5, 'gb__min_samples_leaf': 100, 'gb__l2_regularization': 1.1524074278637269}. Best is trial 15 with value: 0.7122148284019028.
# [I 2026-06-28 23:13:14,247] Trial 25 finished with value: 0.7110489581262012 and parameters: {'gb__learning_rate': 0.13589354777432275, 'gb__max_leaf_nodes': 155, 'gb__max_depth': 3, 'gb__min_samples_leaf': 68, 'gb__l2_regularization': 0.9360498595028268}. Best is trial 15 with value: 0.7122148284019028.
# [I 2026-06-28 23:13:17,083] Trial 26 finished with value: 0.7091939122907231 and parameters: {'gb__learning_rate': 0.07404758572523676, 'gb__max_leaf_nodes': 119, 'gb__max_depth': 10, 'gb__min_samples_leaf': 48, 'gb__l2_regularization': 1.3522199508941295}. Best is trial 15 with value: 0.7122148284019028.
# [I 2026-06-28 23:13:18,327] Trial 27 finished with value: 0.7118289407942411 and parameters: {'gb__learning_rate': 0.1948081877152032, 'gb__max_leaf_nodes': 73, 'gb__max_depth': 5, 'gb__min_samples_leaf': 25, 'gb__l2_regularization': 0.7227686680939569}. Best is trial 15 with value: 0.7122148284019028.
# [I 2026-06-28 23:13:24,852] Trial 28 finished with value: 0.7120030457660128 and parameters: {'gb__learning_rate': 0.02348610258845889, 'gb__max_leaf_nodes': 163, 'gb__max_depth': 7, 'gb__min_samples_leaf': 10, 'gb__l2_regularization': 1.0831366841561398}. Best is trial 15 with value: 0.7122148284019028.
# [I 2026-06-28 23:13:32,263] Trial 29 finished with value: 0.6906376904562098 and parameters: {'gb__learning_rate': 0.006159763801939542, 'gb__max_leaf_nodes': 224, 'gb__max_depth': 7, 'gb__min_samples_leaf': 13, 'gb__l2_regularization': 1.0723838180069438}. Best is trial 15 with value: 0.7122148284019028.
# [I 2026-06-28 23:13:39,673] Trial 30 finished with value: 0.7098749872556566 and parameters: {'gb__learning_rate': 0.021542957642034757, 'gb__max_leaf_nodes': 207, 'gb__max_depth': 8, 'gb__min_samples_leaf': 30, 'gb__l2_regularization': 0.9810388387611666}. Best is trial 15 with value: 0.7122148284019028.
# [I 2026-06-28 23:13:47,368] Trial 31 finished with value: 0.690959105597969 and parameters: {'gb__learning_rate': 0.007289325578671197, 'gb__max_leaf_nodes': 168, 'gb__max_depth': 7, 'gb__min_samples_leaf': 46, 'gb__l2_regularization': 1.24712174093383}. Best is trial 15 with value: 0.7122148284019028.
# [I 2026-06-28 23:13:55,702] Trial 32 finished with value: 0.6810487718335368 and parameters: {'gb__learning_rate': 0.0043912128612045125, 'gb__max_leaf_nodes': 146, 'gb__max_depth': 8, 'gb__min_samples_leaf': 57, 'gb__l2_regularization': 1.4511278764208926}. Best is trial 15 with value: 0.7122148284019028.
# [I 2026-06-28 23:14:00,210] Trial 33 finished with value: 0.7102983910009409 and parameters: {'gb__learning_rate': 0.037165458351514524, 'gb__max_leaf_nodes': 130, 'gb__max_depth': 4, 'gb__min_samples_leaf': 15, 'gb__l2_regularization': 1.1476789890401136}. Best is trial 15 with value: 0.7122148284019028.
# [I 2026-06-28 23:14:07,592] Trial 34 finished with value: 0.7096747282051157 and parameters: {'gb__learning_rate': 0.02206892402720381, 'gb__max_leaf_nodes': 114, 'gb__max_depth': 9, 'gb__min_samples_leaf': 34, 'gb__l2_regularization': 0.737594411460144}. Best is trial 15 with value: 0.7122148284019028.
# [I 2026-06-28 23:14:11,083] Trial 35 finished with value: 0.7112807977366049 and parameters: {'gb__learning_rate': 0.11813718143437528, 'gb__max_leaf_nodes': 25, 'gb__max_depth': 3, 'gb__min_samples_leaf': 77, 'gb__l2_regularization': 0.8011154531653308}. Best is trial 15 with value: 0.7122148284019028.
# [I 2026-06-28 23:14:16,413] Trial 36 finished with value: 0.6964046486159574 and parameters: {'gb__learning_rate': 0.01194101755725458, 'gb__max_leaf_nodes': 170, 'gb__max_depth': 5, 'gb__min_samples_leaf': 49, 'gb__l2_regularization': 1.5680552437636548}. Best is trial 15 with value: 0.7122148284019028.
# [I 2026-06-28 23:14:21,832] Trial 37 finished with value: 0.7103943816547659 and parameters: {'gb__learning_rate': 0.05095501186514346, 'gb__max_leaf_nodes': 99, 'gb__max_depth': 10, 'gb__min_samples_leaf': 91, 'gb__l2_regularization': 1.3868733783593783}. Best is trial 15 with value: 0.7122148284019028.
# [I 2026-06-28 23:14:25,914] Trial 38 finished with value: 0.7116723050554885 and parameters: {'gb__learning_rate': 0.07861552161416016, 'gb__max_leaf_nodes': 145, 'gb__max_depth': 4, 'gb__min_samples_leaf': 10, 'gb__l2_regularization': 1.7499306442363425}. Best is trial 15 with value: 0.7122148284019028.
# [I 2026-06-28 23:14:30,233] Trial 39 finished with value: 0.6072866272116706 and parameters: {'gb__learning_rate': 0.0010014961496868494, 'gb__max_leaf_nodes': 81, 'gb__max_depth': 2, 'gb__min_samples_leaf': 64, 'gb__l2_regularization': 0.8345081325356744}. Best is trial 15 with value: 0.7122148284019028.
# [I 2026-06-28 23:14:32,089] Trial 40 finished with value: 0.708974783602194 and parameters: {'gb__learning_rate': 0.2133426126980244, 'gb__max_leaf_nodes': 40, 'gb__max_depth': 7, 'gb__min_samples_leaf': 24, 'gb__l2_regularization': 0.5442763331908027}. Best is trial 15 with value: 0.7122148284019028.
# [I 2026-06-28 23:14:35,528] Trial 41 finished with value: 0.7114611668951368 and parameters: {'gb__learning_rate': 0.17832201531470987, 'gb__max_leaf_nodes': 64, 'gb__max_depth': 5, 'gb__min_samples_leaf': 29, 'gb__l2_regularization': 0.6689628509403347}. Best is trial 15 with value: 0.7122148284019028.
# [I 2026-06-28 23:14:37,769] Trial 42 finished with value: 0.7097380575462291 and parameters: {'gb__learning_rate': 0.11675652670504615, 'gb__max_leaf_nodes': 71, 'gb__max_depth': 8, 'gb__min_samples_leaf': 43, 'gb__l2_regularization': 0.9894016066772632}. Best is trial 15 with value: 0.7122148284019028.
# [I 2026-06-28 23:14:38,971] Trial 43 finished with value: 0.7114627891468535 and parameters: {'gb__learning_rate': 0.2211562315005794, 'gb__max_leaf_nodes': 126, 'gb__max_depth': 5, 'gb__min_samples_leaf': 20, 'gb__l2_regularization': 0.2187380007129831}. Best is trial 15 with value: 0.7122148284019028.
# [I 2026-06-28 23:14:40,956] Trial 44 finished with value: 0.7127356420949054 and parameters: {'gb__learning_rate': 0.16497152737550272, 'gb__max_leaf_nodes': 41, 'gb__max_depth': 6, 'gb__min_samples_leaf': 55, 'gb__l2_regularization': 0.45619800523702897}. Best is trial 44 with value: 0.7127356420949054.
# [I 2026-06-28 23:14:44,926] Trial 45 finished with value: 0.7114209894497538 and parameters: {'gb__learning_rate': 0.0694156709602008, 'gb__max_leaf_nodes': 37, 'gb__max_depth': 6, 'gb__min_samples_leaf': 52, 'gb__l2_regularization': 0.20745545309085955}. Best is trial 44 with value: 0.7127356420949054.
# [I 2026-06-28 23:14:48,648] Trial 46 finished with value: 0.7106677549678061 and parameters: {'gb__learning_rate': 0.09744563350931798, 'gb__max_leaf_nodes': 198, 'gb__max_depth': 6, 'gb__min_samples_leaf': 74, 'gb__l2_regularization': 0.44554833901216784}. Best is trial 44 with value: 0.7127356420949054.
# [I 2026-06-28 23:14:56,894] Trial 47 finished with value: 0.6703674366194938 and parameters: {'gb__learning_rate': 0.0018351360689308764, 'gb__max_leaf_nodes': 144, 'gb__max_depth': 7, 'gb__min_samples_leaf': 95, 'gb__l2_regularization': 1.2827193671529062}. Best is trial 44 with value: 0.7127356420949054.
# [I 2026-06-28 23:14:59,973] Trial 48 finished with value: 0.7101816490732209 and parameters: {'gb__learning_rate': 0.14192972392676556, 'gb__max_leaf_nodes': 168, 'gb__max_depth': 4, 'gb__min_samples_leaf': 84, 'gb__l2_regularization': 1.9965671723320058}. Best is trial 44 with value: 0.7127356420949054.
# [I 2026-06-28 23:15:03,647] Trial 49 finished with value: 0.690797791313837 and parameters: {'gb__learning_rate': 0.028249419553771096, 'gb__max_leaf_nodes': 16, 'gb__max_depth': 2, 'gb__min_samples_leaf': 60, 'gb__l2_regularization': 1.0902346772816487}. Best is trial 44 with value: 0.7127356420949054.
# [I 2026-06-28 23:15:07,196] Trial 50 finished with value: 0.7106670359045938 and parameters: {'gb__learning_rate': 0.09615521307221993, 'gb__max_leaf_nodes': 194, 'gb__max_depth': 6, 'gb__min_samples_leaf': 108, 'gb__l2_regularization': 0.8942363806401469}. Best is trial 44 with value: 0.7127356420949054.
# [I 2026-06-28 23:15:09,154] Trial 51 finished with value: 0.7109000016697353 and parameters: {'gb__learning_rate': 0.19134468053285794, 'gb__max_leaf_nodes': 46, 'gb__max_depth': 5, 'gb__min_samples_leaf': 33, 'gb__l2_regularization': 0.620945813933008}. Best is trial 44 with value: 0.7127356420949054.
# [I 2026-06-28 23:15:10,613] Trial 52 finished with value: 0.7108563928245505 and parameters: {'gb__learning_rate': 0.231310324092178, 'gb__max_leaf_nodes': 76, 'gb__max_depth': 6, 'gb__min_samples_leaf': 41, 'gb__l2_regularization': 0.7683788620889326}. Best is trial 44 with value: 0.7127356420949054.
# [I 2026-06-28 23:15:12,551] Trial 53 finished with value: 0.7121439758041379 and parameters: {'gb__learning_rate': 0.16690338011730407, 'gb__max_leaf_nodes': 56, 'gb__max_depth': 4, 'gb__min_samples_leaf': 19, 'gb__l2_regularization': 0.47707591763083423}. Best is trial 44 with value: 0.7127356420949054.
# [I 2026-06-28 23:15:14,140] Trial 54 finished with value: 0.7114557428977781 and parameters: {'gb__learning_rate': 0.25508910801010787, 'gb__max_leaf_nodes': 255, 'gb__max_depth': 4, 'gb__min_samples_leaf': 21, 'gb__l2_regularization': 0.384518127135948}. Best is trial 44 with value: 0.7127356420949054.
# [I 2026-06-28 23:15:17,461] Trial 55 finished with value: 0.7118178376606529 and parameters: {'gb__learning_rate': 0.1495840186905163, 'gb__max_leaf_nodes': 55, 'gb__max_depth': 3, 'gb__min_samples_leaf': 52, 'gb__l2_regularization': 0.22575069547666354}. Best is trial 44 with value: 0.7127356420949054.
# [I 2026-06-28 23:15:20,827] Trial 56 finished with value: 0.7111506262216318 and parameters: {'gb__learning_rate': 0.11481083397908443, 'gb__max_leaf_nodes': 95, 'gb__max_depth': 4, 'gb__min_samples_leaf': 36, 'gb__l2_regularization': 1.2004437312299032}. Best is trial 44 with value: 0.7127356420949054.
# [I 2026-06-28 23:15:22,628] Trial 57 finished with value: 0.7111115010229021 and parameters: {'gb__learning_rate': 0.27327927844890904, 'gb__max_leaf_nodes': 158, 'gb__max_depth': 3, 'gb__min_samples_leaf': 17, 'gb__l2_regularization': 0.4933456261658373}. Best is trial 44 with value: 0.7127356420949054.
# [I 2026-06-28 23:15:24,517] Trial 58 finished with value: 0.7116050410797821 and parameters: {'gb__learning_rate': 0.1780980296050843, 'gb__max_leaf_nodes': 123, 'gb__max_depth': 5, 'gb__min_samples_leaf': 28, 'gb__l2_regularization': 1.330746230397028}. Best is trial 44 with value: 0.7127356420949054.
# [I 2026-06-28 23:15:28,976] Trial 59 finished with value: 0.7083995839077543 and parameters: {'gb__learning_rate': 0.04834460302610336, 'gb__max_leaf_nodes': 182, 'gb__max_depth': 4, 'gb__min_samples_leaf': 146, 'gb__l2_regularization': 0.33728134330274234}. Best is trial 44 with value: 0.7127356420949054.
# [I 2026-06-28 23:15:33,422] Trial 60 finished with value: 0.7110329463699724 and parameters: {'gb__learning_rate': 0.06113688074959746, 'gb__max_leaf_nodes': 139, 'gb__max_depth': 6, 'gb__min_samples_leaf': 69, 'gb__l2_regularization': 0.12242313660947607}. Best is trial 44 with value: 0.7127356420949054.
# [I 2026-06-28 23:15:34,974] Trial 61 finished with value: 0.7112256001242658 and parameters: {'gb__learning_rate': 0.16204915728125363, 'gb__max_leaf_nodes': 66, 'gb__max_depth': 5, 'gb__min_samples_leaf': 44, 'gb__l2_regularization': 0.5919126547522657}. Best is trial 44 with value: 0.7127356420949054.
# [I 2026-06-28 23:15:36,644] Trial 62 finished with value: 0.7100757669672709 and parameters: {'gb__learning_rate': 0.12681170646990497, 'gb__max_leaf_nodes': 49, 'gb__max_depth': 5, 'gb__min_samples_leaf': 10, 'gb__l2_regularization': 0.853570250400073}. Best is trial 44 with value: 0.7127356420949054.
# [I 2026-06-28 23:15:40,651] Trial 63 finished with value: 0.7114128800827582 and parameters: {'gb__learning_rate': 0.08443546399145127, 'gb__max_leaf_nodes': 30, 'gb__max_depth': 4, 'gb__min_samples_leaf': 27, 'gb__l2_regularization': 1.0172578940346773}. Best is trial 44 with value: 0.7127356420949054.
# [I 2026-06-28 23:15:42,469] Trial 64 finished with value: 0.7097629333547569 and parameters: {'gb__learning_rate': 0.2082338909343824, 'gb__max_leaf_nodes': 104, 'gb__max_depth': 7, 'gb__min_samples_leaf': 56, 'gb__l2_regularization': 1.1159370199368948}. Best is trial 44 with value: 0.7127356420949054.
# [I 2026-06-28 23:15:45,283] Trial 65 finished with value: 0.7110852557594588 and parameters: {'gb__learning_rate': 0.1748432547018579, 'gb__max_leaf_nodes': 85, 'gb__max_depth': 3, 'gb__min_samples_leaf': 20, 'gb__l2_regularization': 0.6835120215233536}. Best is trial 44 with value: 0.7127356420949054.
# [I 2026-06-28 23:15:46,426] Trial 66 finished with value: 0.7100944597027927 and parameters: {'gb__learning_rate': 0.29164176097547634, 'gb__max_leaf_nodes': 55, 'gb__max_depth': 6, 'gb__min_samples_leaf': 37, 'gb__l2_regularization': 0.4310458525427806}. Best is trial 44 with value: 0.7127356420949054.
# [I 2026-06-28 23:15:50,763] Trial 67 finished with value: 0.7115031478223697 and parameters: {'gb__learning_rate': 0.10974090578610125, 'gb__max_leaf_nodes': 152, 'gb__max_depth': 4, 'gb__min_samples_leaf': 175, 'gb__l2_regularization': 0.9366436306288408}. Best is trial 44 with value: 0.7127356420949054.
# [I 2026-06-28 23:15:56,992] Trial 68 finished with value: 0.7094920574025154 and parameters: {'gb__learning_rate': 0.039655886496548484, 'gb__max_leaf_nodes': 131, 'gb__max_depth': 8, 'gb__min_samples_leaf': 64, 'gb__l2_regularization': 1.2474215631699908}. Best is trial 44 with value: 0.7127356420949054.
# [I 2026-06-28 23:15:59,274] Trial 69 finished with value: 0.7108186089455155 and parameters: {'gb__learning_rate': 0.14075745984925134, 'gb__max_leaf_nodes': 115, 'gb__max_depth': 5, 'gb__min_samples_leaf': 25, 'gb__l2_regularization': 1.43393750717672}. Best is trial 44 with value: 0.7127356420949054.
# [I 2026-06-28 23:16:02,733] Trial 70 finished with value: 0.6762315630250144 and parameters: {'gb__learning_rate': 0.01482791535425585, 'gb__max_leaf_nodes': 34, 'gb__max_depth': 2, 'gb__min_samples_leaf': 199, 'gb__l2_regularization': 0.2753465050847539}. Best is trial 44 with value: 0.7127356420949054.
# [I 2026-06-28 23:16:06,966] Trial 71 finished with value: 0.7118395949412804 and parameters: {'gb__learning_rate': 0.1542361503542819, 'gb__max_leaf_nodes': 58, 'gb__max_depth': 3, 'gb__min_samples_leaf': 53, 'gb__l2_regularization': 0.27534379631542316}. Best is trial 44 with value: 0.7127356420949054.
# [I 2026-06-28 23:16:11,031] Trial 72 finished with value: 0.659049727577603 and parameters: {'gb__learning_rate': 0.00373745983609473, 'gb__max_leaf_nodes': 58, 'gb__max_depth': 3, 'gb__min_samples_leaf': 48, 'gb__l2_regularization': 0.15215568685915637}. Best is trial 44 with value: 0.7127356420949054.
# [I 2026-06-28 23:16:13,354] Trial 73 finished with value: 0.7110426275112385 and parameters: {'gb__learning_rate': 0.2455688835564809, 'gb__max_leaf_nodes': 43, 'gb__max_depth': 3, 'gb__min_samples_leaf': 54, 'gb__l2_regularization': 0.5080190200206931}. Best is trial 44 with value: 0.7127356420949054.
# [I 2026-06-28 23:16:14,926] Trial 74 finished with value: 0.7105781458146272 and parameters: {'gb__learning_rate': 0.19341649380855494, 'gb__max_leaf_nodes': 20, 'gb__max_depth': 4, 'gb__min_samples_leaf': 33, 'gb__l2_regularization': 0.2952808673864021}. Best is trial 44 with value: 0.7127356420949054.
# [I 2026-06-28 23:16:18,307] Trial 75 finished with value: 0.7131808971327804 and parameters: {'gb__learning_rate': 0.15859755278940366, 'gb__max_leaf_nodes': 90, 'gb__max_depth': 2, 'gb__min_samples_leaf': 16, 'gb__l2_regularization': 0.9460892213825202}. Best is trial 75 with value: 0.7131808971327804.
# [I 2026-06-28 23:16:21,851] Trial 76 finished with value: 0.7116295269226185 and parameters: {'gb__learning_rate': 0.10280822762221983, 'gb__max_leaf_nodes': 90, 'gb__max_depth': 2, 'gb__min_samples_leaf': 17, 'gb__l2_regularization': 0.9674788314329933}. Best is trial 75 with value: 0.7131808971327804.
# [I 2026-06-28 23:16:25,634] Trial 77 finished with value: 0.7110078239996901 and parameters: {'gb__learning_rate': 0.13139815093249416, 'gb__max_leaf_nodes': 104, 'gb__max_depth': 2, 'gb__min_samples_leaf': 40, 'gb__l2_regularization': 1.0366545074076992}. Best is trial 75 with value: 0.7131808971327804.
# [I 2026-06-28 23:16:29,981] Trial 78 finished with value: 0.7105594010015615 and parameters: {'gb__learning_rate': 0.06905040910189295, 'gb__max_leaf_nodes': 161, 'gb__max_depth': 3, 'gb__min_samples_leaf': 60, 'gb__l2_regularization': 0.40012648372647003}. Best is trial 75 with value: 0.7131808971327804.
# [I 2026-06-28 23:16:33,871] Trial 79 finished with value: 0.7119328665778415 and parameters: {'gb__learning_rate': 0.1581437281781035, 'gb__max_leaf_nodes': 137, 'gb__max_depth': 2, 'gb__min_samples_leaf': 74, 'gb__l2_regularization': 1.2196272778195667}. Best is trial 75 with value: 0.7131808971327804.
# [I 2026-06-28 23:16:37,718] Trial 80 finished with value: 0.7080229553749098 and parameters: {'gb__learning_rate': 0.07971197984395277, 'gb__max_leaf_nodes': 141, 'gb__max_depth': 2, 'gb__min_samples_leaf': 10, 'gb__l2_regularization': 1.1923859880134913}. Best is trial 75 with value: 0.7131808971327804.
# [I 2026-06-28 23:16:41,316] Trial 81 finished with value: 0.71127048337675 and parameters: {'gb__learning_rate': 0.16418230874865064, 'gb__max_leaf_nodes': 150, 'gb__max_depth': 2, 'gb__min_samples_leaf': 76, 'gb__l2_regularization': 1.3381590201488995}. Best is trial 75 with value: 0.7131808971327804.
# [I 2026-06-28 23:16:44,761] Trial 82 finished with value: 0.7113070756027925 and parameters: {'gb__learning_rate': 0.15283772160820028, 'gb__max_leaf_nodes': 125, 'gb__max_depth': 2, 'gb__min_samples_leaf': 84, 'gb__l2_regularization': 1.4814294868571098}. Best is trial 75 with value: 0.7131808971327804.
# [I 2026-06-28 23:16:48,458] Trial 83 finished with value: 0.7109835786445636 and parameters: {'gb__learning_rate': 0.1296387132360773, 'gb__max_leaf_nodes': 135, 'gb__max_depth': 3, 'gb__min_samples_leaf': 67, 'gb__l2_regularization': 1.1313346838677454}. Best is trial 75 with value: 0.7131808971327804.
# [I 2026-06-28 23:16:52,973] Trial 84 finished with value: 0.7112464483765166 and parameters: {'gb__learning_rate': 0.0923462633019398, 'gb__max_leaf_nodes': 80, 'gb__max_depth': 3, 'gb__min_samples_leaf': 44, 'gb__l2_regularization': 1.2211167166963304}. Best is trial 75 with value: 0.7131808971327804.
# [I 2026-06-28 23:16:56,415] Trial 85 finished with value: 0.7120257698192782 and parameters: {'gb__learning_rate': 0.2273350271269893, 'gb__max_leaf_nodes': 174, 'gb__max_depth': 2, 'gb__min_samples_leaf': 31, 'gb__l2_regularization': 1.394051304754094}. Best is trial 75 with value: 0.7131808971327804.
# [I 2026-06-28 23:16:59,433] Trial 86 finished with value: 0.7116994407894385 and parameters: {'gb__learning_rate': 0.23409397089690231, 'gb__max_leaf_nodes': 172, 'gb__max_depth': 2, 'gb__min_samples_leaf': 17, 'gb__l2_regularization': 1.5284699045734753}. Best is trial 75 with value: 0.7131808971327804.
# [I 2026-06-28 23:17:02,832] Trial 87 finished with value: 0.7126847970825947 and parameters: {'gb__learning_rate': 0.19681398700808292, 'gb__max_leaf_nodes': 113, 'gb__max_depth': 2, 'gb__min_samples_leaf': 32, 'gb__l2_regularization': 1.3894320115099648}. Best is trial 75 with value: 0.7131808971327804.
# [I 2026-06-28 23:17:06,138] Trial 88 finished with value: 0.712038737306246 and parameters: {'gb__learning_rate': 0.21325185284460677, 'gb__max_leaf_nodes': 109, 'gb__max_depth': 2, 'gb__min_samples_leaf': 32, 'gb__l2_regularization': 1.5829348192142825}. Best is trial 75 with value: 0.7131808971327804.
# [I 2026-06-28 23:17:09,007] Trial 89 finished with value: 0.711525879301946 and parameters: {'gb__learning_rate': 0.2611305794723255, 'gb__max_leaf_nodes': 110, 'gb__max_depth': 2, 'gb__min_samples_leaf': 30, 'gb__l2_regularization': 1.6577846732014303}. Best is trial 75 with value: 0.7131808971327804.
# [I 2026-06-28 23:17:16,403] Trial 90 finished with value: 0.6743608152282695 and parameters: {'gb__learning_rate': 0.0014763499321426151, 'gb__max_leaf_nodes': 114, 'gb__max_depth': 7, 'gb__min_samples_leaf': 32, 'gb__l2_regularization': 1.386512814374056}. Best is trial 75 with value: 0.7131808971327804.
# [I 2026-06-28 23:17:19,466] Trial 91 finished with value: 0.71257163942511 and parameters: {'gb__learning_rate': 0.22740229520365907, 'gb__max_leaf_nodes': 100, 'gb__max_depth': 2, 'gb__min_samples_leaf': 23, 'gb__l2_regularization': 1.6409478657776437}. Best is trial 75 with value: 0.7131808971327804.
# [I 2026-06-28 23:17:22,689] Trial 92 finished with value: 0.7129778914334141 and parameters: {'gb__learning_rate': 0.22491945272711125, 'gb__max_leaf_nodes': 120, 'gb__max_depth': 2, 'gb__min_samples_leaf': 23, 'gb__l2_regularization': 1.8144517520724406}. Best is trial 75 with value: 0.7131808971327804.
# [I 2026-06-28 23:17:26,106] Trial 93 finished with value: 0.712691664054494 and parameters: {'gb__learning_rate': 0.20921399846603844, 'gb__max_leaf_nodes': 97, 'gb__max_depth': 2, 'gb__min_samples_leaf': 23, 'gb__l2_regularization': 1.839548323822234}. Best is trial 75 with value: 0.7131808971327804.
# [I 2026-06-28 23:17:29,467] Trial 94 finished with value: 0.713183892161268 and parameters: {'gb__learning_rate': 0.20195128455037306, 'gb__max_leaf_nodes': 97, 'gb__max_depth': 2, 'gb__min_samples_leaf': 22, 'gb__l2_regularization': 1.7777384758317385}. Best is trial 94 with value: 0.713183892161268.
# [I 2026-06-28 23:17:32,738] Trial 95 finished with value: 0.7119265185984472 and parameters: {'gb__learning_rate': 0.1877188779281219, 'gb__max_leaf_nodes': 96, 'gb__max_depth': 2, 'gb__min_samples_leaf': 23, 'gb__l2_regularization': 1.8231446960512931}. Best is trial 94 with value: 0.713183892161268.
# [I 2026-06-28 23:17:35,431] Trial 96 finished with value: 0.7114574229141277 and parameters: {'gb__learning_rate': 0.27987864653352534, 'gb__max_leaf_nodes': 101, 'gb__max_depth': 2, 'gb__min_samples_leaf': 14, 'gb__l2_regularization': 1.860074493360526}. Best is trial 94 with value: 0.713183892161268.
# [I 2026-06-28 23:17:38,537] Trial 97 finished with value: 0.7135479403067547 and parameters: {'gb__learning_rate': 0.19596046609990694, 'gb__max_leaf_nodes': 120, 'gb__max_depth': 2, 'gb__min_samples_leaf': 21, 'gb__l2_regularization': 1.81418620346617}. Best is trial 97 with value: 0.7135479403067547.
# [I 2026-06-28 23:17:41,767] Trial 98 finished with value: 0.7121973115343568 and parameters: {'gb__learning_rate': 0.20108371788408433, 'gb__max_leaf_nodes': 93, 'gb__max_depth': 2, 'gb__min_samples_leaf': 21, 'gb__l2_regularization': 1.7700402868303526}. Best is trial 97 with value: 0.7135479403067547.
# [I 2026-06-28 23:17:45,212] Trial 99 finished with value: 0.7124857840220339 and parameters: {'gb__learning_rate': 0.19417105977404395, 'gb__max_leaf_nodes': 95, 'gb__max_depth': 2, 'gb__min_samples_leaf': 26, 'gb__l2_regularization': 1.7732044569852332}. Best is trial 97 with value: 0.7135479403067547.

# %%
trials_df = study.trials_dataframe()

top5_optuna = (trials_df[trials_df["state"] == "COMPLETE"].sort_values("value", ascending=False).loc[:, [
        "number",
        "value",
        "params_gb__learning_rate",
        "params_gb__max_leaf_nodes",
        "params_gb__max_depth",
        "params_gb__min_samples_leaf",
        "params_gb__l2_regularization"
    ]].head(5).rename(columns={
        "number": "trial",
        "value": "mean_f1",
        "params_gb__learning_rate": "learning_rate",
        "params_gb__max_leaf_nodes": "max_leaf_nodes",
        "params_gb__max_depth": "max_depth",
        "params_gb__min_samples_leaf": "min_samples_leaf",
        "params_gb__l2_regularization": "l2_regularization"
    })
)

display(top5_optuna)
# Out:
#     trial   mean_f1  learning_rate  max_leaf_nodes  max_depth  \
# 97     97  0.713548       0.195960             120          2
# 94     94  0.713184       0.201951              97          2
# 75     75  0.713181       0.158598              90          2
# 92     92  0.712978       0.224919             120          2
# 44     44  0.712736       0.164972              41          6
#
#     min_samples_leaf  l2_regularization
# 97                21           1.814186
# 94                22           1.777738
# 75                16           0.946089
# 92                23           1.814452
# 44                55           0.456198

# %%
print(f"Best Optuna mean F1: {study.best_value:.4f}")
print("Best Optuna parameters:")
print(study.best_params)
# Out:
# Best Optuna mean F1: 0.7135
# Best Optuna parameters:
# {'gb__learning_rate': 0.19596046609990694, 'gb__max_leaf_nodes': 120, 'gb__max_depth': 2, 'gb__min_samples_leaf': 21, 'gb__l2_regularization': 1.81418620346617}

# %% [markdown]
# ### Problem 3 Graded Answer
#
# Set `a3` to the mean F1 score of the best model found.

# %%
 # Your answer here

a3 = study.best_value                    # replace 0 with your answer, may copy from the displayed results

# %%
# DO NOT change this cell in any way

print(f'a3 = {a3:.4f}')
# Out:
# a3 = 0.7135

# %% [markdown]
# ## Problem 4: Final Model Evaluation on Test Set
#
# In this problem, you will take the best hyperparameter configuration you found in your earlier experiments (Randomized Search or Optuna) and fully evaluate the resulting model on the test set.
#
# **Background:**
# When performing hyperparameter tuning, we typically optimize for a single metric (e.g., F1). However, before deployment, it is essential to check **all relevant metrics** on the final test set to understand the model’s behavior in a balanced way.
#
# **Instructions:**
#
# 1. Take the best hyperparameters you found in Problems 2 or 3 and apply them to your `pipelined_model`.
# 2. Re-train this final tuned model on the **entire training set** (not just the folds).
# 3. Evaluate the final model on the heldout **test set**, reporting the following metrics:
#
#    * Precision
#    * Recall
#    * F1 score
#    * Balanced accuracy
# 4. Use `classification_report` **on the test set** to print precision, recall, and F1 score, and use `balanced_accuracy_score` separately to calculate and print balanced accuracy.
# 5. Answer the graded questions.
#
# **Note:** We evaluate the metrics on the test set because it was never seen during training or hyperparameter tuning. This gives us an unbiased estimate of how the model will perform on truly unseen data. Evaluating on the training set would be misleading, because the model has already learned from that data and could appear artificially good.

# %%
# Your code here
best_params = study.best_params

final_model = clone(pipelined_model)
final_model.set_params(**best_params)

final_model.fit(X_train, y_train)
y_pred = final_model.predict(X_test)

report = classification_report(y_test,y_pred,target_names=["<=50K", ">50K"],output_dict=True)
print(classification_report(y_test,y_pred,target_names=["<=50K", ">50K"]))
# Out:
#               precision    recall  f1-score   support
#
#        <=50K       0.95      0.82      0.88      7431
#         >50K       0.61      0.87      0.72      2338
#
#     accuracy                           0.83      9769
#    macro avg       0.78      0.85      0.80      9769
# weighted avg       0.87      0.83      0.84      9769

# %%
test_precision = precision_score(y_test, y_pred)
test_recall = recall_score(y_test, y_pred)
test_f1 = f1_score(y_test, y_pred)
test_balanced_accuracy = balanced_accuracy_score(y_test, y_pred)

print(f"Test Precision: {test_precision:.4f}")
print(f"Test Recall: {test_recall:.4f}")
print(f"Test F1 Score: {test_f1:.4f}")
print(f"Test Balanced Accuracy: {test_balanced_accuracy:.4f}")
# Out:
# Test Precision: 0.6083
# Test Recall: 0.8700
# Test F1 Score: 0.7159
# Test Balanced Accuracy: 0.8468

# %% [markdown]
# ### Problem 4 Graded Questions
#
# - Set `a4a` to the balanced accuracy score of the best model.
# - Set `a4b` to the macro average precision of this model.
# - Set `a4c` to the macro average recall score of the this model.
#
# **Note:** Macro average takes the mean of each class’s precision/recall without considering how many samples each class has, which is appropriate for a balanced evaluation.

# %%
 # Your answer here

a4a = test_balanced_accuracy                    # replace 0 with your answer, use variable or expression from above

# %%
# DO NOT change this cell in any way

print(f'a4a = {a4a:.4f}')
# Out:
# a4a = 0.8468

# %%
 # Your answer here

a4b = report["macro avg"]["precision"]                     # replace 0 with your answer, may copy from the displayed results

# %%
# DO NOT change this cell in any way

print(f'a4b = {a4b:.4f}')
# Out:
# a4b = 0.7805

# %%
 # Your answer here

a4c = report["macro avg"]["recall"]                    # replace 0 with your answer, may copy from the displayed results

# %%
# DO NOT change this cell in any way

print(f'a4c = {a4c:.4f}')
# Out:
# a4c = 0.8468

# %% [markdown]
# ###  Problem 5 Graded Question (multiple choice)
#
# A bank uses your model to identify customers earning over $50K for a premium product invitation. Based on your final test set evaluation, including macro-averaged precision and recall, which of the following best describes what might happen?
#
# (1) The bank will miss some eligible high-income customers, but will avoid marketing mistakes by sending invitations only to those it is  confident about.
#
# (2) The bank will successfully reach most high-income customers, but will also waste resources sending invitations to some low-income customers.
#
# (3) The bank will perfectly identify all high-income and low-income customers, resulting in no wasted invitations and no missed opportunities.
#
# (4) The bank will correctly identify most high-income customers while also sending invitations to very few low-income customers, because a high F1 score guarantees both high precision and high recall.

# %%
 # Your answer here

a5 = 0                     # replace 0 with one of 1, 2, or 3

# %%
# DO NOT change this cell in any way

print(f'a5 = {a5}')
# Out:
# a5 = 0

# %% [markdown]
# ## **Problem Five: Analytical Questions**
#
# Select the single **best** answer to each of the following multiple choice questions on this week's material.
#
# You may wish to review Appendix One for a brief tutorial on the various classification metrics.

# %% [markdown]
# ### Part A: Tests - Precision, Recall, and F1 in Practice
#
# A bank uses your model to identify customers earning over $50K for a premium product invitation. Based on your final test set evaluation, including macro-averaged precision and recall, which of the following best describes what might happen?
#
# 1. The bank will miss some eligible high-income customers, but will avoid marketing mistakes by sending invitations only to those it is  confident about.
#
# 2. The bank will successfully reach most high-income customers, but will also waste resources sending invitations to some low-income customers.
#
# 3. The bank will perfectly identify all high-income and low-income customers, resulting in no wasted invitations and no missed opportunities.
#
# 4. The bank will correctly identify most high-income customers while also sending invitations to very few low-income customers, because a high F1 score guarantees both high precision and high recall.

# %%
# Your answer here. 

a5a = 2                    # Must be one of 1, 2, 3, 4

# %%
### Do not change this cell in any way

print(f'a5a = {a5a}')
# Out:
# a5a = 2

# %% [markdown]
# ### Part B: Why Use Stratified Cross-Validation?
#
# Why is **StratifiedKFold** preferred over ordinary **KFold** for this homework?
#
# 1. It guarantees every fold has exactly the same number of observations.
# 2. It keeps approximately the same class proportions in every fold.
# 3. It prevents overfitting by using more training samples.
# 4. It automatically balances the training data by duplicating minority-class examples.

# %%
# Your answer here. 

a5b = 2                    # Must be one of 1, 2, 3, 4

# %%
# Do not change this cell in any way

print(f'a5b = {a5b}')
# Out:
# a5b = 2

# %% [markdown]
# ### Part C: Understanding Precision and Recall
#
# Suppose you lower the probability threshold used to classify someone as earning more than $50K.
#
# Which change is **most likely**?
#
# 1. Precision increases while recall decreases.
# 2. Both precision and recall increase.
# 3. Recall increases while precision decreases.
# 4. Precision, recall, and F1 always remain unchanged.

# %%
# Your answer here. 

a5c = 3                    # Must be one of 1, 2, 3, 4

# %%
# Do not change this cell in any way

print(f'a5c = {a5c}')
# Out:
# a5c = 3

# %% [markdown]
# ### Part D: Why Use a Pipeline?
#
# The homework places the `OrdinalEncoder` inside a `Pipeline` instead of encoding the entire dataset before cross-validation.
#
# What is the primary reason?
#
# 1. Pipelines train the classifier faster.
# 2. Pipelines reduce the number of hyperparameters.
# 3. Pipelines prevent data leakage during cross-validation.
# 4. Pipelines automatically improve F1 score.

# %%
# Your answer here. 

a5d = 3                    # Must be one of 1, 2, 3, 4

# %%
# Do not change this cell in any way

print(f'a5d = {a5d}')
# Out:
# a5d = 3

# %% [markdown]
# ### Part E: Early Stopping
#
# `HistGradientBoostingClassifier` is configured with a large value of `max_iter` while enabling **early stopping**.
#
# Why is this a good strategy?
#
# 1. It guarantees the model reaches the maximum number of iterations.
# 2. It allows training to stop automatically once additional iterations no longer improve validation performance.
# 3. It eliminates the need for cross-validation.
# 4. It ensures the model never overfits.

# %%
# Your answer here. 

a5e = 2                   # Must be one of 1, 2, 3, 4

# %%
# Do not change this cell in any way

print(f'a5e = {a5e}')
# Out:
# a5e = 2

# %% [markdown]
# ### Appendix One: Understanding Precision, Recall, F1, and Balanced Accuracy
#
# **Tutorial**
#
# In binary classification, you will often evaluate these key metrics:
#
# * **Precision**: *Of all the positive predictions the model made, how many were actually correct?*
#
#   * High precision = few false positives
#   * Low precision = many false positives
#
# * **Recall**: *Of all the actual positive cases, how many did the model correctly identify?*
#
#   * High recall = few false negatives
#   * Low recall = many false negatives
#
# * **F1 score**: The harmonic mean of precision and recall, which balances them in a single measure.
#
#   * F1 is **highest** when precision and recall are both high and similar in value.
#   * If precision and recall are unbalanced, F1 will drop to reflect that imbalance.
#
# * **Balanced accuracy**: The average of recall across both classes (positive and negative).
#
#   * It ensures the classifier is performing reasonably well on *both* groups, correcting for class imbalance.
#   * Balanced accuracy is especially important if the classes are very unequal in size.
#
# **Typical trade-offs to remember:**
#
# * **Higher recall, lower precision**: the model finds most true positives but also mislabels some negatives as positives
# * **Higher precision, lower recall**: the model is strict about positive predictions, but misses some true positives
# * **Balanced precision and recall (good F1)**: a practical compromise
# * **Balanced accuracy**: checks fairness across both classes

# %% [markdown]
# ### Appendix Two: Feature Engineering
#
# Here are some practical feature-engineering tweaks worth considering (beyond simply ordinal-encoding the categoricals)
#
# | Feature(s)                                                           | Why the tweak can help                                                                                                                                                     | How to do it (quick version)                                                                                                                                                    | Keep / drop?      |
# | -------------------------------------------------------------------- | -------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------- |
# | **`fnlwgt`**                                                         | Survey sampling weight, not a predictor. Leaving it in often lets the model “cheat.”                                                                                       | `df = df.drop(columns=["fnlwgt"])`                                                                                                                                              | **Drop**          |
# | **`education` *vs.* `education-num`**                                | They encode the **same** information twice (categorical label and its ordinal rank). Keeping both is redundant and can cause leakage of a perfectly predictive feature.    | Usually keep **only one**. For tree models `education-num` is simplest: `df = df.drop(columns=["education"])`                                                                   | **Drop one**      |
# | **`capital-gain`, `capital-loss`**                                   | Highly skewed; most values are zero with a long upper tail. The sign (gain vs. loss) matters, but treating them separately wastes a feature slot.                          | 1) Combine: `df["capital_net"] = df["capital-gain"] - df["capital-loss"]`; 2) Log-transform to reduce skew: `df["capital_net_log"] = np.log1p(df["capital_net"].clip(lower=0))` | Replace originals |
# | **`age`, `hours-per-week`**                                          | Continuous but with natural plateaus—trees handle splits fine, yet log or square-root scaling can soften extreme values; bucketing makes partial-dependence plots clearer. | Simple bucket: `df["age_bin"] = pd.cut(df["age"], bins=[16,25,35,45,55,65,90])` (optional)                                                                                      | Optional          |
# | **Missing categories** (`workclass`, `occupation`, `native-country`) | HGB handles `-1`/`-2` codes fine, but you may want *explicit* “Missing” bucket for interpretability.                                                                       | Use `encoded_missing_value=-2` during encoding.                                                                                                            | Keep as is        |
# | **Rare categories in `native-country`**                              | Hundreds of low-frequency countries dilute signal; grouping boosts stability.                                                                                              | Map infrequent categories to “Other”:                                                                                                                                           |                   |
#
#
# #### Minimum set of tweaks (good baseline, low effort)
#
# 1. **Drop `fnlwgt`.**
# 2. **Keep `education-num`, drop `education`.**
# 3. **Combine `capital-gain` and `capital-loss` into `capital_net`** (optionally add a log-scaled version).
# 4. Leave other numeric/categorical features as is; your histogram-GBDT will cope.
